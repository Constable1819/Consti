# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Arabela

# %% [markdown]
# Engineer

# %% [markdown]
# *I am interested in data science because I would like to use it in my lab analysis*

# %% [markdown]
# ### The next code should diplay 14 divided by 43

# %%
14/43
# Out:
# 0.32558139534883723

# %% [markdown]
# * pig
# * goat
# * cow
# * sheep
#
# ![beyoncé.jpg](attachment:d8a16718-6c3a-482d-925b-065c7234ec0a.jpg)
#
# [Click here to watch Pretty Hurts video](https://www.youtube.com/watch?v=LXXQLa-5n5w)
